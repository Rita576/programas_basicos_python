# %%
def has_duplicatas(s):
  t = list(s)
  t.sort()
  
  for c in range(len(t)-1):
    if t[c] == t[c+1]:
      return True
    else:
      return False

print(has_duplicatas('1,1,2,2,3'))
print(has_duplicatas('abcd'))
# Out:
# True
# False
