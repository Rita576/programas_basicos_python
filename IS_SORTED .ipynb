# %%
"UTILIZEI A QUESTAO 1 PARA ESTA"
def is_sorted(t):
  soma=0
  lista2 = []
  for x in t:
    soma += x
    lista2.append(soma)
  return t == sorted(t)

print(is_sorted([7,3,4,5]))
print(is_sorted([1,2,3,4]))
# Out:
# False
# True
